# %% [markdown]
# # ARP - Random Sampling for Categorisation of Datasets

# %%
import pandas as pd
import random
from nltk.sentiment.vader import SentimentIntensityAnalyzer
import nltk

# Ensure you have downloaded the VADER lexicon
nltk.download('vader_lexicon')
analyzer = SentimentIntensityAnalyzer()
# Out:
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     /Users/Jey/nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!

# %% [markdown]
# # Fiat 600e

# %% [markdown]
# ## 600e - YouTube Comments

# %%
# Load the dataset
file_path = '600e - Potential Customers.csv'
comments_df = pd.read_csv(file_path)

# Display the first few rows to understand the structure
print(comments_df.head())
# Out:
#          Date           ID                                               Text
# 0  2024-03-08  AXGNb76QgH0                              25000 is a fair price
# 1  2024-03-04  AXGNb76QgH0  it looks solid and i know its a great driving ...
# 2  2024-02-24  AXGNb76QgH0  really love the video and review of new fiat 6...
# 3  2024-02-16  AXGNb76QgH0  imagine if fiat invested in perfecting the 500...
# 4  2024-02-13  AXGNb76QgH0  my wife has a 500 c and all we love it nobody ...

# %%
comments_df.shape
# Out:
# (1148, 3)

# %%
# Step 2: Random Sampling
# Set sample size to 5 percent of the total number of comments
sample_size = int(0.05 * comments_df.shape[0])
print(f"Sample size: {sample_size}")
sampled_comments = comments_df.sample(n=sample_size, random_state=3)
# Out:
# Sample size: 57

# %%
sampled_comments
# Out:
#             Date           ID  \
# 314   2023-09-23  VokQJrHzBR8
# 845   2023-09-27  ejT6GwY6cSY
# 119   2024-04-09  MvgfB8kcS1s
# 518   2023-09-27  ejT6GwY6cSY
# 740   2023-09-26  ejT6GwY6cSY
# 303   2023-09-24  VokQJrHzBR8
# 1053  2023-09-26  ejT6GwY6cSY
# 103   2024-05-03  MvgfB8kcS1s
# 505   2023-09-28  ejT6GwY6cSY
# 91    2023-10-10  AXGNb76QgH0
# 1141  2024-03-10  FknVzDA15bE
# 288   2023-09-26  VokQJrHzBR8
# 596   2023-09-27  ejT6GwY6cSY
# 376   2023-09-23  VokQJrHzBR8
# 585   2023-09-27  ejT6GwY6cSY
# 389   2023-09-23  VokQJrHzBR8
# 407   2023-11-28  VokQJrHzBR8
# 944   2023-09-27  ejT6GwY6cSY
# 266   2023-10-03  Z6vFfBmTXuA
# 144   2024-04-07  MvgfB8kcS1s
# 689   2023-09-26  ejT6GwY6cSY
# 197   2024-03-08  eZMrw98nHgU
# 873   2023-09-29  ejT6GwY6cSY
# 915   2023-09-26  ejT6GwY6cSY
# 235   2023-09-28  HAZC8wrWQGM
# 352   2023-09-23  VokQJrHzBR8
# 606   2023-09-27  ejT6GwY6cSY
# 157   2024-04-07  MvgfB8kcS1s
# 304   2023-09-24  VokQJrHzBR8
# 669   2023-09-26  ejT6GwY6cSY
# 201   2024-03-10  eZMrw98nHgU
# 578   2023-09-27  ejT6GwY6cSY
# 953   2023-09-26  ejT6GwY6cSY
# 526   2023-09-27  ejT6GwY6cSY
# 988   2023-09-26  ejT6GwY6cSY
# 323   2023-09-23  VokQJrHzBR8
# 880   2023-10-01  ejT6GwY6cSY
# 386   2023-09-23  VokQJrHzBR8
# 193   2024-03-09  eZMrw98nHgU
# 415   2023-09-23  VokQJrHzBR8
# 557   2023-09-27  ejT6GwY6cSY
# 324   2023-09-23  VokQJrHzBR8
# 896   2023-09-26  ejT6GwY6cSY
# 1013  2023-09-26  ejT6GwY6cSY
# 948   2023-09-26  ejT6GwY6cSY
# 290   2023-09-25  VokQJrHzBR8
# 523   2023-10-07  ejT6GwY6cSY
# 85    2023-10-05  AXGNb76QgH0
# 249   2023-09-28  HAZC8wrWQGM
# 652   2023-09-26  ejT6GwY6cSY
# 548   2023-09-27  ejT6GwY6cSY
# 243   2023-09-27  HAZC8wrWQGM
# 967   2023-09-26  ejT6GwY6cSY
# 539   2023-09-27  ejT6GwY6cSY
# 95    2023-10-17  AXGNb76QgH0
# 210   2024-03-08  eZMrw98nHgU
# 574   2023-09-27  ejT6GwY6cSY
#
#                                                    Text
# 314       plus was there mention of charging speeds etc
# 845   xxwookey 35 grand is not the entry fee at all ...
# 119   bill_heywood so their balanced approach seems ...
# 518   pro tip for the producers of the show please w...
# 740   this is another disappointing ev it illustrate...
# 303   my favourite part of this review was when look...
# 1053  much more interesting than the 500 doesnt look...
# 103   stupid fiat taken out the interial mood lighti...
# 505   stopped watching when you suggested that one p...
# 91    youre way behind the times i had a fiat for ye...
# 1141  good evening totallyev im a recent subscriber ...
# 288   what about a review on the nio el6 and the et5...
# 596   durability reliability and life cycle costs ba...
# 376   little gerry did you get out of bed on the wro...
# 585   this should be headline news as only the disco...
# 389   ive been driving a 500e for the last 20 months...
# 407   nowadays all car makers share platforms and te...
# 944   bmwhp2 id personally be fine with an ev that c...
# 266   is it impossible to design a good looking ev b...
# 144   autosocialuk love the audio for when youre not...
# 689   smallsimpleoverpriced as meatloaf would say 2 ...
# 197   have you ever seen this 4500 charge on ev char...
# 873   christopherhume8896 im willing to bet it doesn...
# 915           its time the norm was under 30kwell under
# 235      the cutesy face is a bit too much cartoon like
# 352   nicola did i got it right that you said in thi...
# 606                              there are national car
# 157   i was kind of gutted about the space in the ba...
# 304   haha i was trying to see if there was a centra...
# 669   nice car nice color nice overall design except...
# 201                     yes chinese byd burn your drive
# 578   just bought a 1 year old vivaro e life elite f...
# 953   i hate one pedal driving so its good to see it...
# 526   liters come on fully charged spell things corr...
# 988   jonathansmith5850 mg do what if youre referrin...
# 323    600e all the way or id3 never the chinese brands
# 880   i buy used cars for 3k45k and theyre great mak...
# 386   stellantis must be the worst car conglomerate ...
# 193   thats because your ioniq 5 is dystopian future...
# 415   another great review thx shame it doesnt look ...
# 557   you gotta love bs martketing stunts i went on ...
# 324   the trouble with girls a car is just a thing t...
# 896   for comparison my tesla model 3 gets 299 watts...
# 1013  price is mentioned at 515 entry level price is...
# 948   robertdodge yet brexit is about to have us add...
# 290   cant wait for the hybrid to come to the uk itl...
# 523   nickclarkuk if your wages have gone up in line...
# 85            cute car for first car owners and drivers
# 249   oceanthirteen1628 this i agree with we shouldn...
# 652   cant understand why brand after brand bring ou...
# 548   once again the hyundai kona is still the cheap...
# 243   as a car guy id spend that kind of money on a ...
# 967   no wonder the eu are going to spank tariffs on...
# 539   cheap are you mentally challenged unless this ...
# 95    nice design the italian flag on the bumper tho...
# 210   i dont understand you fuff about the innovativ...
# 574   whats the battery chemistry what kind of batte...

# %%
# Step 3: Refine Manual Review and Categorisation
def categorize_comment(Text):
    current_customer_keywords = [
    "my fiat", "i own", "i drive", "my car", "as an owner", "my 600e", "i have", "ive had", 
    "i bought", "i purchased", "im driving", "im using", "my vehicle",
    "driving my", "owned", "have owned", "currently own", "currently driving", 
    "i’ve driven", "my experience", "experiencing with", "have been using", "have been driving",
    "my ride", "in my fiat", "my journey with", "ownership of", "been driving", 
    "loving my", "bought my", "recently purchased", "enjoying my", "love driving"
   ]
    potential_customer_keywords = [
        "worth", "better", "if", "whether", "thinking", "think", "thought", "buying", "buy", 
        "considering", "consider", "considered", "looking to", "interested in", "planned", 
        "plan to", "planning to", "want", "wanted", "getting", "get", "available", "how much", 
        "prefer", "budget", "cost", "price", "than", "new car", "first car", "next car", 
        "decision", "decide", "decision", "deciding", "choose", "choice", "would love", 
        "purchase", "whats the", "what about", "is it", "does it", "when will", "test drive", 
        "lease", "financing", "finance options", "payment", "dealer", "dealership", 
        "excited about", "curious about", "researching", "research", "looking into", 
        "exploring", "versus", "vs", "as good as", "compared to", "alternative", "impressed", 
        "amazing", "fantastic", "great", "good", "review", "opinion", "feedback", "would you", 
        "recommend", "should i", "like it", "loving it", "love it","budget"
    ]

    for keyword in current_customer_keywords:
        if keyword in Text:
            return 'Current Customers'
    for keyword in potential_customer_keywords:
        if keyword in Text:
            return 'Potential Customers'
    return 'General Public'

# Apply categorisation
sampled_comments['Category'] = sampled_comments['Text'].apply(categorize_comment)

# %%
# Calculate Percentages
total_comments = len(sampled_comments)
percent_current = round((sampled_comments['Category'] == 'Current Customers').sum() / total_comments * 100, 2)
percent_potential = round((sampled_comments['Category'] == 'Potential Customers').sum() / total_comments * 100, 2)
percent_general = round((sampled_comments['Category'] == 'General Public').sum() / total_comments * 100, 2)

# Display the results
print(f"600e - YT Comments Percentage of Current Customers: {percent_current}%")
print(f"600e - YT Comments Percentage of Potential Customers: {percent_potential}%")
print(f"600e - YT Comments Percentage of General Public: {percent_general}%")
# Out:
# 600e - YT Comments Percentage of Current Customers: 7.02%
# 600e - YT Comments Percentage of Potential Customers: 66.67%
# 600e - YT Comments Percentage of General Public: 26.32%

# %% [markdown]
# # Fiat 500e

# %% [markdown]
# ## 500e - YouTube Comments

# %%
# Load the dataset
file_path = '500e - YouTube Comments_Clean.csv'
comments_df = pd.read_csv(file_path)

# Display the first few rows to understand the structure
print(comments_df.head())
# Out:
#          Date           ID                                               Text
# 0  2024-05-04  0kDbvxpjLZs  9 seconds for an electric car thats especially...
# 1  2024-02-16  0kDbvxpjLZs  good honest review thanks like the car im in a...
# 2  2024-01-06  0kDbvxpjLZs  this is a genius car this is a car that you do...
# 3  2023-10-21  0kDbvxpjLZs  got a twinair mito done 60k in it its great th...
# 4  2023-09-16  0kDbvxpjLZs  no spare wheel is a dealbreaker i love that ga...

# %%
comments_df.shape
# Out:
# (2540, 3)

# %%
# Step 2: Random Sampling
sample_size = int(0.05 * comments_df.shape[0])
print(f"Sample size: {sample_size}")
sampled_comments = comments_df.sample(n=sample_size, random_state=3)
# Out:
# Sample size: 127

# %%
sampled_comments
# Out:
#             Date           ID  \
# 1875  2020-12-02  JSwvQE0tgyM
# 617   2022-11-29  pMJ2fEhN-Vc
# 1691  2020-12-02  JSwvQE0tgyM
# 2323  2024-06-03  OSvuSISisD8
# 2517  2024-06-03  OSvuSISisD8
# ...          ...          ...
# 2199  2024-05-08  R-NFILq5hhA
# 1048  2021-02-03  JSwvQE0tgyM
# 838   2022-11-28  pMJ2fEhN-Vc
# 972   2023-02-18  JSwvQE0tgyM
# 2371  2024-06-03  OSvuSISisD8
#
#                                                    Text
# 1875  i have to say of all the small ev cars the fia...
# 617   hubnut good luck with affordable heating this ...
# 1691  ok sorry i typically do 5050 ev and piston stu...
# 2323  but then again the mitsubishi mirage only has ...
# 2517  they are going to sit on the lot for several m...
# ...                                                 ...
# 2199  i only drive 50 miles a month would love to ha...
# 1048                          is this a four seater car
# 838   the timing does say it all they only show up t...
# 972      whats the range of the 42kwh at constant 70mph
# 2371  a cute runabout for the city fiat fans might l...
#
# [127 rows x 3 columns]

# %%
# Step 3: Refine Manual Review and Categorisation
def categorize_comment(Text):
    current_customer_keywords = [
    "my fiat", "i own", "i drive", "my car", "as an owner", "my 600e", "i have", "ive had", 
    "i bought", "i purchased", "im driving", "im using", "my vehicle",
    "driving my", "owned", "have owned", "currently own", "currently driving", 
    "i’ve driven", "my experience", "experiencing with", "have been using", "have been driving",
    "my ride", "in my fiat", "my journey with", "ownership of", "been driving", 
    "loving my", "bought my", "recently purchased", "enjoying my", "love driving"
   ]
    potential_customer_keywords = [
        "worth", "better", "if", "whether", "thinking", "think", "thought", "buying", "buy", 
        "considering", "consider", "considered", "looking to", "interested in", "planned", 
        "plan to", "planning to", "want", "wanted", "getting", "get", "available", "how much", 
        "prefer", "budget", "cost", "price", "than", "new car", "first car", "next car", 
        "decision", "decide", "decision", "deciding", "choose", "choice", "would love", 
        "purchase", "whats the", "what about", "is it", "does it", "when will", "test drive", 
        "lease", "financing", "finance options", "payment", "dealer", "dealership", 
        "excited about", "curious about", "researching", "research", "looking into", 
        "exploring", "versus", "vs", "as good as", "compared to", "alternative", "impressed", 
        "amazing", "fantastic", "great", "good", "review", "opinion", "feedback", "would you", 
        "recommend", "should i", "like it", "loving it", "love it","budget"
    ]

    for keyword in current_customer_keywords:
        if keyword in Text:
            return 'Current Customers'
    for keyword in potential_customer_keywords:
        if keyword in Text:
            return 'Potential Customers'
    return 'General Public'

# Apply categorisation
sampled_comments['Category'] = sampled_comments['Text'].apply(categorize_comment)

# %%
# Calculate Percentages
total_comments = len(sampled_comments)
percent_current = round((sampled_comments['Category'] == 'Current Customers').sum() / total_comments * 100, 2)
percent_potential = round((sampled_comments['Category'] == 'Potential Customers').sum() / total_comments * 100, 2)
percent_general = round((sampled_comments['Category'] == 'General Public').sum() / total_comments * 100, 2)

# Display the results
print(f"500e - YT Comments Percentage of Current Customers: {percent_current}%")
print(f"500e - YT Comments Percentage of Potential Customers: {percent_potential}%")
print(f"500e - YT Comments Percentage of General Public: {percent_general}%")
# Out:
# 500e - YT Comments Percentage of Current Customers: 7.09%
# 500e - YT Comments Percentage of Potential Customers: 71.65%
# 500e - YT Comments Percentage of General Public: 21.26%

# %% [markdown]
# ## 500e - Forums

# %%
forum_speakev = pd.read_csv('500e - SpeakEV_Clean.csv')
forum_ph = pd.read_csv('500e - PistonHeads_Clean.csv')

# Merge the two dataframes
forums_df = pd.concat([forum_speakev, forum_ph], ignore_index=True)

# Keep only data after March 2020
forums_df['Date'] = pd.to_datetime(forums_df['Date'])
forums_df = forums_df[forums_df['Date'] >= '2020-03-01']

# %%
# Display the first few rows to understand the structure
print(forums_df.head())
# Out:
#         Date                                                URL  \
# 0 2023-07-21  https://www.speakev.com/threads/fiat-500e-icon...
# 1 2023-08-17  https://www.speakev.com/threads/what-charging-...
# 2 2022-10-22  https://www.speakev.com/threads/fiat-500e-serv...
# 3 2023-09-12  https://www.speakev.com/threads/thoughts-on-th...
# 4 2023-09-26  https://www.speakev.com/threads/fiat-500e-char...
#
#                                                 Text
# 0  hi there we will receive our new fiat 500e ico...
# 1  hi there i have ordered a fiat 500e icon on le...
# 2  i had my 2015 fiat 500e shipped from ca a few ...
# 3  the latest fiat 500e la prima designio by kahn...
# 4  is there a way to delete not just unselect a c...

# %%
forums_df.shape
# Out:
# (246, 3)

# %%
# Step 2: Random Sampling
sample_size = int(0.05 * forums_df.shape[0])
print(f"Sample size: {sample_size}")
sampled_forums = forums_df.sample(n=sample_size, random_state=5)
# Out:
# Sample size: 12

# %%
sampled_forums
# Out:
#           Date                                                URL  \
# 60  2022-05-08  https://www.speakev.com/threads/no-ev-made-it-...
# 57  2022-08-22  https://www.speakev.com/threads/hello-from-lux...
# 180 2022-08-25  https://www.speakev.com/threads/smart-fortwo-e...
# 833 2023-08-21  https://www.pistonheads.com/gassing/topic.asp?...
# 52  2023-12-07  https://www.speakev.com/threads/are-dumb-home-...
# 698 2022-02-01  https://www.pistonheads.com/gassing/topic.asp?...
# 900 2021-12-31  https://www.pistonheads.com/gassing/topic.asp?...
# 64  2021-11-27  https://www.speakev.com/threads/miles-per-kwh-...
# 736 2020-07-21  https://www.pistonheads.com/gassing/topic.asp?...
# 85  2021-05-20  https://www.speakev.com/threads/sold-zoe-22kwh...
# 743 2020-07-21  https://www.pistonheads.com/gassing/topic.asp?...
# 117 2021-11-14  https://www.speakev.com/threads/how-to-work-wi...
#
#                                                   Text
# 60   as predicted or not tesla has disappeared from...
# 57   moien im änder from luxembourg aged 44 and las...
# 180  i am close to making the decision to get my fi...
# 833  be serious weight is irrelevant because it has...
# 52   hi all i have had my nissan leaf since 2016 ty...
# 698  ive got one had it since nov ours is very much...
# 900  had one 5 mths and sold it as an experienced e...
# 64   dort had 500e 3 months now and energy in is wo...
# 736  we had an i3 a few years ago and she loved it ...
# 85   hi having joined the ev revolution in 2016 wit...
# 743  one thing that puzzles me about the interior o...
# 117  hi with 100 battery remaining mileage is 200mi...

# %%
# Step 3: Refine Manual Review and Categorisation
def categorize_comment(Text):
    current_customer_keywords = [
    "my fiat", "i own", "i drive", "my car", "as an owner", "my 600e", "i have", "ive had", 
    "i bought", "i purchased", "im driving", "im using", "my vehicle",
    "driving my", "owned", "have owned", "currently own", "currently driving", 
    "i’ve driven", "my experience", "experiencing with", "have been using", "have been driving",
    "my ride", "in my fiat", "my journey with", "ownership of", "been driving", 
    "loving my", "bought my", "recently purchased", "enjoying my", "love driving"
   ]
    potential_customer_keywords = [
        "worth", "better", "if", "whether", "thinking", "think", "thought", "buying", "buy", 
        "considering", "consider", "considered", "looking to", "interested in", "planned", 
        "plan to", "planning to", "want", "wanted", "getting", "get", "available", "how much", 
        "prefer", "budget", "cost", "price", "than", "new car", "first car", "next car", 
        "decision", "decide", "decision", "deciding", "choose", "choice", "would love", 
        "purchase", "whats the", "what about", "is it", "does it", "when will", "test drive", 
        "lease", "financing", "finance options", "payment", "dealer", "dealership", 
        "excited about", "curious about", "researching", "research", "looking into", 
        "exploring", "versus", "vs", "as good as", "compared to", "alternative", "impressed", 
        "amazing", "fantastic", "great", "good", "review", "opinion", "feedback", "would you", 
        "recommend", "should i", "like it", "loving it", "love it","budget"
    ]

    for keyword in current_customer_keywords:
        if keyword in Text:
            return 'Current Customers'
    for keyword in potential_customer_keywords:
        if keyword in Text:
            return 'Potential Customers'
    return 'General Public'

# Apply categorisation
sampled_forums['Category'] = sampled_forums['Text'].apply(categorize_comment)

# %%
# Calculate Percentages
total_forums = len(sampled_forums)
percent_current = round((sampled_forums['Category'] == 'Current Customers').sum() / total_forums * 100, 2)
percent_potential = round((sampled_forums['Category'] == 'Potential Customers').sum() / total_forums * 100, 2)
percent_general = round((sampled_forums['Category'] == 'General Public').sum() / total_forums * 100, 2)

# Display the results
print(f"500e - Forums Percentage of Current Customers: {percent_current}%")
print(f"500e - Forums Percentage of Potential Customers: {percent_potential}%")
print(f"500e - Forums Percentage of General Public: {percent_general}%")
# Out:
# 500e - Forums Percentage of Current Customers: 33.33%
# 500e - Forums Percentage of Potential Customers: 58.33%
# 500e - Forums Percentage of General Public: 8.33%

# %% [markdown]
# ## 500e - YouTube Comments + Forums (Merged Dataset)

# %%
# Load the dataset
file_path = '500e - Potential Customers.csv'
comments_forums_df = pd.read_csv(file_path)

# Display the first few rows to understand the structure
comments_forums_df.head()
# Out:
#          Date   Source                                               Text
# 0  2023-07-21  SpeakEV  hi there we will receive our new fiat 500e ico...
# 1  2023-08-17  SpeakEV  hi there i have ordered a fiat 500e icon on le...
# 2  2022-10-22  SpeakEV  i had my 2015 fiat 500e shipped from ca a few ...
# 3  2023-09-12  SpeakEV  the latest fiat 500e la prima designio by kahn...
# 4  2023-09-26  SpeakEV  is there a way to delete not just unselect a c...

# %%
comments_forums_df.shape
# Out:
# (2786, 3)

# %%
# Step 2: Random Sampling
sample_size = int(0.05 * comments_forums_df.shape[0])
print(f"Sample size: {sample_size}")
sampled_comments_forums = comments_forums_df.sample(n=sample_size, random_state=5)
# Out:
# Sample size: 139

# %%
sampled_comments_forums
# Out:
#             Date           Source  \
# 1410  2020-12-05  YouTube Comment
# 413   2021-06-03  YouTube Comment
# 982   2022-11-28  YouTube Comment
# 1688  2020-12-02  YouTube Comment
# 1236  2022-01-21  YouTube Comment
# ...          ...              ...
# 1275  2021-04-14  YouTube Comment
# 2609  2024-06-03  YouTube Comment
# 1239  2021-12-13  YouTube Comment
# 1067  2022-11-28  YouTube Comment
# 2281  2024-04-11  YouTube Comment
#
#                                                    Text
# 1410  this 500e is perfect for the week than the amg...
# 413        nikki is a great presenter love the fiat too
# 982   i could be attracted to an ev but why oh why a...
# 1688  thelatebrakeshow no worries made me cackle thi...
# 1236  wait till the italian made electrics start foo...
# ...                                                 ...
# 1275  sherpa i think of a mountain climber like 4x4 ...
# 2609  forest i have a challenge car for you a 2009 m...
# 1239  please stop to compare with honda fiat is a fi...
# 1067  my old renault scenic 06 did that if i was sto...
# 2281  allentechpt9026 you mean my class a cdl with e...
#
# [139 rows x 3 columns]

# %%
# Step 3: Refine Manual Review and Categorisation
def categorize_comment(Text):
    current_customer_keywords = [
    "my fiat", "i own", "i drive", "my car", "as an owner", "my 600e", "i have", "ive had", 
    "i bought", "i purchased", "im driving", "im using", "my vehicle",
    "driving my", "owned", "have owned", "currently own", "currently driving", 
    "i’ve driven", "my experience", "experiencing with", "have been using", "have been driving",
    "my ride", "in my fiat", "my journey with", "ownership of", "been driving", 
    "loving my", "bought my", "recently purchased", "enjoying my", "love driving"
   ]
    potential_customer_keywords = [
        "worth", "better", "if", "whether", "thinking", "think", "thought", "buying", "buy", 
        "considering", "consider", "considered", "looking to", "interested in", "planned", 
        "plan to", "planning to", "want", "wanted", "getting", "get", "available", "how much", 
        "prefer", "budget", "cost", "price", "than", "new car", "first car", "next car", 
        "decision", "decide", "decision", "deciding", "choose", "choice", "would love", 
        "purchase", "whats the", "what about", "is it", "does it", "when will", "test drive", 
        "lease", "financing", "finance options", "payment", "dealer", "dealership", 
        "excited about", "curious about", "researching", "research", "looking into", 
        "exploring", "versus", "vs", "as good as", "compared to", "alternative", "impressed", 
        "amazing", "fantastic", "great", "good", "review", "opinion", "feedback", "would you", 
        "recommend", "should i", "like it", "loving it", "love it","budget"
    ]

    for keyword in current_customer_keywords:
        if keyword in Text:
            return 'Current Customers'
    for keyword in potential_customer_keywords:
        if keyword in Text:
            return 'Potential Customers'
    return 'General Public'

# Apply categorisation
sampled_comments_forums['Category'] = sampled_comments_forums['Text'].apply(categorize_comment)

# %%
# Calculate Percentages
total_comments_forums = len(sampled_comments_forums)
percent_current = round((sampled_comments_forums['Category'] == 'Current Customers').sum() / total_comments_forums * 100, 2)
percent_potential = round((sampled_comments_forums['Category'] == 'Potential Customers').sum() / total_comments_forums * 100, 2)
percent_general = round((sampled_comments_forums['Category'] == 'General Public').sum() / total_comments_forums * 100, 2)

# Display the results
print(f"500e - Merged YT Comments + Forums Percentage of Current Customers: {percent_current}%")
print(f"500e - Merged YT Comments + Forums  Percentage of Potential Customers: {percent_potential}%")
print(f"500e - Merged YT Comments + Forums  Percentage of General Public: {percent_general}%")
# Out:
# 500e - Merged YT Comments + Forums Percentage of Current Customers: 10.79%
# 500e - Merged YT Comments + Forums  Percentage of Potential Customers: 63.31%
# 500e - Merged YT Comments + Forums  Percentage of General Public: 25.9%
