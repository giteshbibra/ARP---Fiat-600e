# %% [markdown]
# # ARP - Data Cleaning of Forums

# %%
import pandas as pd
import numpy as np
import re

# %% [markdown]
# # 500e - Cleaning SpeakEV Forum Threads

# %%
# Read csv file
df_speakev = pd.read_csv('500e - SpeakEV_20240724.csv')

# %%
# Rename Content column to Text
df_speakev.rename(columns={'Content': 'Text'}, inplace=True)
df_speakev.head(15)
# Out:
#                                                   URL  \
# 0   https://www.speakev.com/forums/EV-Classifieds/...
# 1   https://www.speakev.com/threads/fiat-500e-icon...
# 2   https://www.speakev.com/threads/what-charging-...
# 3   https://www.speakev.com/threads/fiat-500e-serv...
# 4   https://www.speakev.com/threads/thoughts-on-th...
# 5   https://www.speakev.com/threads/fiat-500e-char...
# 6   https://www.speakev.com/threads/first-car-fiat...
# 7   https://www.speakev.com/threads/fiat-500e-easy...
# 8   https://www.speakev.com/threads/fiat-500e-for-...
# 9   https://www.speakev.com/threads/fiat-500e-inte...
# 10  https://www.speakev.com/threads/my-verdict-on-...
# 11  https://www.speakev.com/threads/thinking-about...
# 12  https://www.speakev.com/threads/fiat-500e-la-p...
# 13  https://www.speakev.com/threads/fiat-500e-serv...
# 14  https://www.speakev.com/threads/fiat-500e-serv...
#
#                    Timestamp  \
# 0   2024-06-18T03:53:34-0400
# 1   2023-07-21T17:45:04-0400
# 2   2023-08-17T15:55:28-0400
# 3   2022-10-22T14:03:40-0400
# 4   2023-09-12T09:05:29-0400
# 5   2023-09-26T16:00:17-0400
# 6   2023-08-18T04:40:53-0400
# 7   2022-02-03T18:13:44-0500
# 8   2021-11-16T04:35:47-0500
# 9   2024-02-24T11:47:28-0500
# 10  2023-07-14T17:37:48-0400
# 11  2023-08-03T08:50:29-0400
# 12  2022-09-12T08:02:35-0400
# 13  2021-09-07T05:44:21-0400
# 14  2023-10-01T10:34:14-0400
#
#                                                 Title  \
# 0                                                 NaN
# 1                       Fiat 500e Icon Charging Cable
# 2   What charging cables come with the fiat 500e i...
# 3              Fiat 500e service in Seattle/Eastside?
# 4         Thoughts on the Fiat 500e Designio by Kahn?
# 5                         Fiat 500e - charging issues
# 6                       First Car Fiat 500E Icon 2022
# 7          Fiat 500e EasyWallBox Charger Installation
# 8                     Fiat 500e For Sale on UK Plates
# 9                  Fiat 500e intelligent speed assist
# 10  My verdict on the charging situation on Orkney...
# 11  Thinking about shipping our 2013 Fiat 500e to ...
# 12             Fiat 500e La Prima " Beep when locked"
# 13                        Fiat 500e service intervals
# 14                        FIAT 500e Service Intervals
#
#                                                  Text
# 0                                   Content not found
# 1   Hi There\n\nWe will receive our new fiat 500e ...
# 2   Hi there \n\nI have ordered a fiat 500e icon o...
# 3   I had my 2015 Fiat 500e shipped from CA a few ...
# 4   The latest Fiat 500e La Prima Designio by Kahn...
# 5   Is there a way to delete (not just 'unselect')...
# 6   Hello Everyone \n\nI have bought a Fiat 500E I...
# 7   Hi All, \n\nI was wondering if anyone had any ...
# 8   Don’t see many of these outside LA. If I hadn’...
# 9   Do any other 500e drivers have issues with the...
# 10  We spent 12 days out of 143 during the Fiat 50...
# 11  I enjoy driving our little Fiat 500e over in C...
# 12  Hiya. \n\nWe have just had delivered a new Fia...
# 13  Hi,\nWe are close to ordering a new fiat 500e,...
# 14  My rented 500e is one year old today. I got it...

# %% [markdown]
# Convert to string values:

# %%
# Convert 'Text' column to string to handle non-string types
df_speakev['Text'] = df_speakev['Text'].astype(str)

# %% [markdown]
# Adjust to lowercase:

# %%
# Adjust 'Text' column to lowercase
df_speakev['Text'] = df_speakev['Text'].str.lower()

# %% [markdown]
# Remove punctuation:

# %%
# Remove punctuation 
def remove_punctuation(text):
    return re.sub(r'[^\w\s]', '', text)

# Apply the functions to the 'Content' column
df_speakev['Text'] = df_speakev['Text'].apply(remove_punctuation)

# %% [markdown]
# Adjust timestamp:

# %%
# Split the 'Timestamp' into 'Date' and 'Time' and keep only the 'Date'
df_speakev['Date'] = df_speakev['Timestamp'].str.split('T', expand=True)[0]

# Move 'Date' to the first column
cols = ['Date'] + [col for col in df_speakev.columns if col != 'Date']
df_speakev = df_speakev[cols]

# Drop the 'Timestamp' 
df_speakev.drop('Timestamp', axis=1, inplace=True)

# Preview the cleaned data
df_speakev.head(15)
# Out:
#           Date                                                URL  \
# 0   2024-06-18  https://www.speakev.com/forums/EV-Classifieds/...
# 1   2023-07-21  https://www.speakev.com/threads/fiat-500e-icon...
# 2   2023-08-17  https://www.speakev.com/threads/what-charging-...
# 3   2022-10-22  https://www.speakev.com/threads/fiat-500e-serv...
# 4   2023-09-12  https://www.speakev.com/threads/thoughts-on-th...
# 5   2023-09-26  https://www.speakev.com/threads/fiat-500e-char...
# 6   2023-08-18  https://www.speakev.com/threads/first-car-fiat...
# 7   2022-02-03  https://www.speakev.com/threads/fiat-500e-easy...
# 8   2021-11-16  https://www.speakev.com/threads/fiat-500e-for-...
# 9   2024-02-24  https://www.speakev.com/threads/fiat-500e-inte...
# 10  2023-07-14  https://www.speakev.com/threads/my-verdict-on-...
# 11  2023-08-03  https://www.speakev.com/threads/thinking-about...
# 12  2022-09-12  https://www.speakev.com/threads/fiat-500e-la-p...
# 13  2021-09-07  https://www.speakev.com/threads/fiat-500e-serv...
# 14  2023-10-01  https://www.speakev.com/threads/fiat-500e-serv...
#
#                                                 Title  \
# 0                                                 NaN
# 1                       Fiat 500e Icon Charging Cable
# 2   What charging cables come with the fiat 500e i...
# 3              Fiat 500e service in Seattle/Eastside?
# 4         Thoughts on the Fiat 500e Designio by Kahn?
# 5                         Fiat 500e - charging issues
# 6                       First Car Fiat 500E Icon 2022
# 7          Fiat 500e EasyWallBox Charger Installation
# 8                     Fiat 500e For Sale on UK Plates
# 9                  Fiat 500e intelligent speed assist
# 10  My verdict on the charging situation on Orkney...
# 11  Thinking about shipping our 2013 Fiat 500e to ...
# 12             Fiat 500e La Prima " Beep when locked"
# 13                        Fiat 500e service intervals
# 14                        FIAT 500e Service Intervals
#
#                                                  Text
# 0                                   content not found
# 1   hi there\n\nwe will receive our new fiat 500e ...
# 2   hi there \n\ni have ordered a fiat 500e icon o...
# 3   i had my 2015 fiat 500e shipped from ca a few ...
# 4   the latest fiat 500e la prima designio by kahn...
# 5   is there a way to delete not just unselect a c...
# 6   hello everyone \n\ni have bought a fiat 500e i...
# 7   hi all \n\ni was wondering if anyone had any a...
# 8   dont see many of these outside la if i hadnt j...
# 9   do any other 500e drivers have issues with the...
# 10  we spent 12 days out of 143 during the fiat 50...
# 11  i enjoy driving our little fiat 500e over in c...
# 12  hiya \n\nwe have just had delivered a new fiat...
# 13  hi\nwe are close to ordering a new fiat 500e b...
# 14  my rented 500e is one year old today i got it ...

# %% [markdown]
# Remove empty rows and internal whitespace:

# %%
# Remove rows where 'Text' is empty or has 2 words or less
df_speakev = df_speakev[df_speakev['Text'].apply(lambda x: isinstance(x, str) and len(x.split()) > 2 and x.strip() != '')]

# Remove leading and trailing whitespace and excessive internal whitespace
df_speakev['Text'] = df_speakev['Text'].str.strip()  # Remove leading and trailing whitespace
df_speakev['Text'] = df_speakev['Text'].apply(lambda x: re.sub(r'\s+', ' ', x))  # Remove excessive internal whitespace

# %%
# Remove specific words and phrases
phrases_to_remove = ['content not found', 'click to expand', 'thanks in advance', 'jeffrey cooper said']
for phrase in phrases_to_remove:
    df_speakev['Text'] = df_speakev['Text'].str.replace(phrase, '', regex=False)

df_speakev.head(15)
# Out:
#           Date                                                URL  \
# 0   2024-06-18  https://www.speakev.com/forums/EV-Classifieds/...
# 1   2023-07-21  https://www.speakev.com/threads/fiat-500e-icon...
# 2   2023-08-17  https://www.speakev.com/threads/what-charging-...
# 3   2022-10-22  https://www.speakev.com/threads/fiat-500e-serv...
# 4   2023-09-12  https://www.speakev.com/threads/thoughts-on-th...
# 5   2023-09-26  https://www.speakev.com/threads/fiat-500e-char...
# 6   2023-08-18  https://www.speakev.com/threads/first-car-fiat...
# 7   2022-02-03  https://www.speakev.com/threads/fiat-500e-easy...
# 8   2021-11-16  https://www.speakev.com/threads/fiat-500e-for-...
# 9   2024-02-24  https://www.speakev.com/threads/fiat-500e-inte...
# 10  2023-07-14  https://www.speakev.com/threads/my-verdict-on-...
# 11  2023-08-03  https://www.speakev.com/threads/thinking-about...
# 12  2022-09-12  https://www.speakev.com/threads/fiat-500e-la-p...
# 13  2021-09-07  https://www.speakev.com/threads/fiat-500e-serv...
# 14  2023-10-01  https://www.speakev.com/threads/fiat-500e-serv...
#
#                                                 Title  \
# 0                                                 NaN
# 1                       Fiat 500e Icon Charging Cable
# 2   What charging cables come with the fiat 500e i...
# 3              Fiat 500e service in Seattle/Eastside?
# 4         Thoughts on the Fiat 500e Designio by Kahn?
# 5                         Fiat 500e - charging issues
# 6                       First Car Fiat 500E Icon 2022
# 7          Fiat 500e EasyWallBox Charger Installation
# 8                     Fiat 500e For Sale on UK Plates
# 9                  Fiat 500e intelligent speed assist
# 10  My verdict on the charging situation on Orkney...
# 11  Thinking about shipping our 2013 Fiat 500e to ...
# 12             Fiat 500e La Prima " Beep when locked"
# 13                        Fiat 500e service intervals
# 14                        FIAT 500e Service Intervals
#
#                                                  Text
# 0
# 1   hi there we will receive our new fiat 500e ico...
# 2   hi there i have ordered a fiat 500e icon on le...
# 3   i had my 2015 fiat 500e shipped from ca a few ...
# 4   the latest fiat 500e la prima designio by kahn...
# 5   is there a way to delete not just unselect a c...
# 6   hello everyone i have bought a fiat 500e icon ...
# 7   hi all i was wondering if anyone had any advic...
# 8   dont see many of these outside la if i hadnt j...
# 9   do any other 500e drivers have issues with the...
# 10  we spent 12 days out of 143 during the fiat 50...
# 11  i enjoy driving our little fiat 500e over in c...
# 12  hiya we have just had delivered a new fiat 500...
# 13  hi we are close to ordering a new fiat 500e bu...
# 14  my rented 500e is one year old today i got it ...

# %% [markdown]
# Drop duplicates under 'Text' column:

# %%
# Check for duplicate content
print(df_speakev.duplicated(subset='Text').sum())

# Drop duplicates
df_speakev.drop_duplicates(subset='Text', inplace=True)
# Out:
# 147

# %%
# Drop 'Title' column
df_speakev.drop('Title', axis=1, inplace=True)

# %%
# Filter such that Content or Title only contains certain key words
keywords = ['500e', 'fiat', 'electric', 'ev', 'stellantis']
df_speakev = df_speakev[df_speakev['Text'].str.contains('|'.join(keywords), case=False)]
len(df_speakev)
# Out:
# 231

# %%
# Save as a new CSV file
df_speakev.to_csv('500e - SpeakEV_Clean_20240730.csv', index=False)

# %% [markdown]
# # 500e - Cleaning PistonHeads Forum Threads

# %%
# Read csv file
df_ph = pd.read_csv('500e - PistonHeads_20240724.csv')

# %%
# Rename Content column to Text
df_ph.rename(columns={'Comment': 'Text'}, inplace=True)
df_ph.head(15)
# Out:
#                         Date  \
# 0     Friday 21st April 2023
# 1     Friday 21st April 2023
# 2     Friday 21st April 2023
# 3     Friday 21st April 2023
# 4     Friday 21st April 2023
# 5     Friday 21st April 2023
# 6     Friday 21st April 2023
# 7     Friday 21st April 2023
# 8     Friday 21st April 2023
# 9   Saturday 22nd April 2023
# 10  Saturday 22nd April 2023
# 11  Saturday 22nd April 2023
# 12   Wednesday 10th May 2023
# 13   Wednesday 10th May 2023
# 14   Wednesday 10th May 2023
#
#                                                   URL  \
# 0   https://www.pistonheads.com/gassing/topic.asp?...
# 1   https://www.pistonheads.com/gassing/topic.asp?...
# 2   https://www.pistonheads.com/gassing/topic.asp?...
# 3   https://www.pistonheads.com/gassing/topic.asp?...
# 4   https://www.pistonheads.com/gassing/topic.asp?...
# 5   https://www.pistonheads.com/gassing/topic.asp?...
# 6   https://www.pistonheads.com/gassing/topic.asp?...
# 7   https://www.pistonheads.com/gassing/topic.asp?...
# 8   https://www.pistonheads.com/gassing/topic.asp?...
# 9   https://www.pistonheads.com/gassing/topic.asp?...
# 10  https://www.pistonheads.com/gassing/topic.asp?...
# 11  https://www.pistonheads.com/gassing/topic.asp?...
# 12  https://www.pistonheads.com/gassing/topic.asp?...
# 13  https://www.pistonheads.com/gassing/topic.asp?...
# 14  https://www.pistonheads.com/gassing/topic.asp?...
#
#                                                 Title  \
# 0   RE: Jaguar announces electric four-door GT for...
# 1   RE: Jaguar announces electric four-door GT for...
# 2   RE: Jaguar announces electric four-door GT for...
# 3   RE: Jaguar announces electric four-door GT for...
# 4   RE: Jaguar announces electric four-door GT for...
# 5   RE: Jaguar announces electric four-door GT for...
# 6   RE: Jaguar announces electric four-door GT for...
# 7   RE: Jaguar announces electric four-door GT for...
# 8   RE: Jaguar announces electric four-door GT for...
# 9   RE: Jaguar announces electric four-door GT for...
# 10  RE: Jaguar announces electric four-door GT for...
# 11  RE: Jaguar announces electric four-door GT for...
# 12  RE: Jaguar announces electric four-door GT for...
# 13  RE: Jaguar announces electric four-door GT for...
# 14  RE: Jaguar announces electric four-door GT for...
#
#                                                  Text
# 0   DonkeyApple said:\n I think full EV is the onl...
# 1   LooneyTunes said:\n Range Rovers of various si...
# 2   That's it, in a nutshell.For as long as anyone...
# 3   Great news.  Just make it beautiful and you wi...
# 4   Robertb said:\n Great news.  Just make it beau...
# 5   blueacid said:\n Hear hear! I'm sad to see the...
# 6   Robertb said:\n Great news.  Just make it beau...
# 7   Julian Scott said:\n\nRobertb said:\n Great ne...
# 8   The problem is with manufacturers going electr...
# 9   Mouse Rat said:\n The problem is with manufact...
# 10  Mouse Rat said:\n The problem is with manufact...
# 11  Mouse Rat said:\n The problem is with manufact...
# 12  In general, Jaguar has been a synonymous with ...
# 13  EVOTECH3BELL said:\n Good news for jobs in the...
# 14  Ingo hj said:\n In general, Jaguar has been a ...

# %% [markdown]
# Convert to string values:

# %%
# Convert 'Text' column to string to handle non-string types
df_ph['Text'] = df_ph['Text'].astype(str)

# %% [markdown]
# Adjust to lowercase:

# %%
# Adjust 'Text' column to lowercase
df_ph['Text'] = df_ph['Text'].str.lower()

# %% [markdown]
# Remove punctuation:

# %%
# Remove punctuation 
def remove_punctuation(text):
    return re.sub(r'[^\w\s]', '', text)

# Define a function to remove phrases like "user said"
def remove_user_said(text):
    return re.sub(r'\b\w+\s+said\s*', '', text, flags=re.IGNORECASE)

# Apply all cleaning functions to the 'Content' column
df_ph['Text'] = df_ph['Text'].apply(remove_punctuation).apply(remove_user_said)

# %% [markdown]
# Adjust timestamp:

# %%
# Convert 'Date' to yyyy-mm-dd format
df_ph['Date'] = pd.to_datetime(df_ph['Date'], errors='coerce').dt.strftime('%Y-%m-%d')

# %% [markdown]
# Remove empty rows and internal whitespace:

# %%
# Remove rows where 'Content' is empty or has 2 words or less
df_ph = df_ph[df_ph['Text'].apply(lambda x: isinstance(x, str) and len(x.split()) > 2 and x.strip() != '')]

# Remove leading and trailing whitespace and excessive internal whitespace
df_ph['Text'] = df_ph['Text'].str.strip()  # Remove leading and trailing whitespace
df_ph['Text'] = df_ph['Text'].apply(lambda x: re.sub(r'\s+', ' ', x))  # Remove excessive internal whitespace

# %%
# Filter such that Text or Title only contains certain key words
keywords = ['500e', 'fiat', 'electric', 'ev', 'stellantis']
df_ph = df_ph[df_ph['Text'].str.contains('|'.join(keywords), case=False)]
len(df_ph)
# Out:
# 729

# %%
# Remove duplicates
df_ph = df_ph.drop_duplicates(subset='Text')
len(df_ph)
# Out:
# 728

# %%
# Drop 'Title' column
df_ph = df_ph.drop(columns=['Title'])

# %%
# Save the filtered dataframe to a new CSV
df_ph.to_csv('500e - PistonHeads_Clean_20240730.csv', index=False)

# %% [markdown]
# ## Merge Datasets

# %%
# Read csv file
df_speakev_clean = pd.read_csv('500e - SpeakEV_Clean_20240730.csv')
df_speakev_clean.head()
# Out:
#          Date                                                URL  \
# 0  2023-07-21  https://www.speakev.com/threads/fiat-500e-icon...
# 1  2023-08-17  https://www.speakev.com/threads/what-charging-...
# 2  2022-10-22  https://www.speakev.com/threads/fiat-500e-serv...
# 3  2023-09-12  https://www.speakev.com/threads/thoughts-on-th...
# 4  2023-09-26  https://www.speakev.com/threads/fiat-500e-char...
#
#                                                 Text
# 0  hi there we will receive our new fiat 500e ico...
# 1  hi there i have ordered a fiat 500e icon on le...
# 2  i had my 2015 fiat 500e shipped from ca a few ...
# 3  the latest fiat 500e la prima designio by kahn...
# 4  is there a way to delete not just unselect a c...

# %%
# Read csv file
df_ph_clean = pd.read_csv('500e - PistonHeads_Clean_20240730.csv')
df_ph_clean.head()
# Out:
#          Date                                                URL  \
# 0  2023-04-21  https://www.pistonheads.com/gassing/topic.asp?...
# 1  2023-04-21  https://www.pistonheads.com/gassing/topic.asp?...
# 2  2023-04-21  https://www.pistonheads.com/gassing/topic.asp?...
# 3  2023-04-21  https://www.pistonheads.com/gassing/topic.asp?...
# 4  2023-04-21  https://www.pistonheads.com/gassing/topic.asp?...
#
#                                                 Text
# 0  i think full ev is the only and last chance fo...
# 1  range rovers of various sizes really are the d...
# 2  thats it in a nutshellfor as long as anyone ca...
# 3  great news just make it beautiful and you will...
# 4  hear hear im sad to see the xj go wonder what ...

# %%
# Merge the two dataframes
df_combined = pd.concat([df_speakev_clean, df_ph_clean], ignore_index=True)

# %%
# Save the combined dataframe to a new CSV
df_combined.to_csv('500e - Forums_Merged_20240730.csv', index=False)

# %% [markdown]
# # 500e - Potential Customers (Merge Forums with YouTube Comments)

# %%
# Read csv file
df_forums = pd.read_csv('500e - Forums_Merged_20240730.csv')
df_comments = pd.read_csv('500e - YouTube Comments_Clean_20240730.csv')

df_forums.head(), df_comments.head()
# Out:
# (         Date                                                URL  \
#  0  2023-07-21  https://www.speakev.com/threads/fiat-500e-icon...
#  1  2023-08-17  https://www.speakev.com/threads/what-charging-...
#  2  2022-10-22  https://www.speakev.com/threads/fiat-500e-serv...
#  3  2023-09-12  https://www.speakev.com/threads/thoughts-on-th...
#  4  2023-09-26  https://www.speakev.com/threads/fiat-500e-char...
#
#                                                  Text
#  0  hi there we will receive our new fiat 500e ico...
#  1  hi there i have ordered a fiat 500e icon on le...
#  2  i had my 2015 fiat 500e shipped from ca a few ...
#  3  the latest fiat 500e la prima designio by kahn...
#  4  is there a way to delete not just unselect a c...  ,
#           Date      VideoID                                            Comment
#  0  2024-05-04  0kDbvxpjLZs  9 seconds for an electric car thats especially...
#  1  2024-02-16  0kDbvxpjLZs  good honest review thanks like the car im in a...
#  2  2024-01-06  0kDbvxpjLZs  this is a genius car this is a car that you do...
#  3  2023-10-21  0kDbvxpjLZs  got a twinair mito done 60k in it its great th...
#  4  2023-09-16  0kDbvxpjLZs  no spare wheel is a dealbreaker i love that ga...)

# %% [markdown]
# Merge the two dataframes:

# %%
# Define the source based on URL for forums
def get_forum_source(url):
    if 'speakev.com' in url:
        return 'SpeakEV'
    elif 'pistonheads.com' in url:
        return 'PistonHeads'
    else:
        return 'Unknown'

# Apply the source definition to the forums dataset
df_forums['Source'] = df_forums['URL'].apply(get_forum_source)

# For YouTube comments, the source is always 'YouTube Comment'
df_comments['Source'] = 'YouTube Comment'

# Select and rename columns to match the desired final dataset
df_forums = df_forums.rename(columns={'Date': 'Date', 'Text': 'Text'})
df_forums = df_forums[['Date', 'Source', 'Text']]

df_comments = df_comments.rename(columns={'Date': 'Date', 'Comment': 'Text'})
df_comments = df_comments[['Date', 'Source', 'Text']]

# Merge the two datasets
df_merge = pd.concat([df_forums, df_comments], ignore_index=True)

# Display the first few rows of the final dataframe
print(df_merge.head())
# Out:
#          Date   Source                                               Text
# 0  2023-07-21  SpeakEV  hi there we will receive our new fiat 500e ico...
# 1  2023-08-17  SpeakEV  hi there i have ordered a fiat 500e icon on le...
# 2  2022-10-22  SpeakEV  i had my 2015 fiat 500e shipped from ca a few ...
# 3  2023-09-12  SpeakEV  the latest fiat 500e la prima designio by kahn...
# 4  2023-09-26  SpeakEV  is there a way to delete not just unselect a c...

# %%
# Save the final merged dataset to a CSV file
df_merge.to_csv('500e - Potential Customers_20240730.csv', index=False)
