# 10  2024-02-13T12:47:22Z  AXGNb76QgH0
# 11  2024-02-13T11:20:00Z  AXGNb76QgH0
# 12  2024-01-28T09:04:16Z  AXGNb76QgH0
# 13  2024-01-21T15:41:29Z  AXGNb76QgH0
# 14  2024-01-11T18:35:05Z  AXGNb76QgH0
#
#                                               Comment
# 0   Ehy do you miss out the 500X its same and hybr...
# 1                        Enjoyed watching, thank you.
# 2              Nobody are liking the eye lits so far.
# 3   Don't follow the worldly trends follow Jesus C...
# 4                               25000 is a fair price
# 5   It looks solid and I know it's a great driving...
# 6   Really love the video and review of new Fiat 6...
# 7   Imagine if Fiat invested in perfecting the 500...
# 8   OMG i hate you shoes.They look like someting o...
# 9   My wife has a 500 C and all we love it. Nobody...
# 10                             Why are most EVs SUVs?
# 11  Lovely quote from The Italian Job at the Lingo...
# 12                                  A french car...😎👍
# 13                                She doesn't like it
# 14  I'll pass because no rear door pockets!😢 just ...

# %%
# Function to remove emojis from a string
def remove_emojis(text):
    emoji_pattern = re.compile(
        "["
        u"\U0001F600-\U0001F64F"  # emoticons
        u"\U0001F300-\U0001F5FF"  # symbols & pictographs
        u"\U0001F680-\U0001F6FF"  # transport & map symbols
        u"\U0001F700-\U0001F77F"  # alchemical symbols
        u"\U0001F780-\U0001F7FF"  # Geometric Shapes Extended
        u"\U0001F800-\U0001F8FF"  # Supplemental Arrows-C
        u"\U0001F900-\U0001F9FF"  # Supplemental Symbols and Pictographs
        u"\U0001FA00-\U0001FA6F"  # Chess Symbols
        u"\U0001FA70-\U0001FAFF"  # Symbols and Pictographs Extended-A
        u"\U00002702-\U000027B0"  # Dingbats
        u"\U000024C2-\U0001F251" 
        "]+", flags=re.UNICODE)
    return emoji_pattern.sub(r'', text)

# Function to remove punctuation from a string
def remove_punctuation(text):
    return re.sub(r'[^\w\s]', '', text)

# Apply the functions to the 'Comment' column
df_600['Comment'] = df_600['Comment'].apply(remove_emojis).apply(remove_punctuation)

# %%
# Preview the cleaned data
df_600.head(15)
# Out:
#                Timestamp      VideoID  \
# 0   2024-05-01T13:34:19Z  AXGNb76QgH0
# 1   2024-04-28T10:14:55Z  AXGNb76QgH0
# 2   2024-04-06T19:20:29Z  AXGNb76QgH0
# 3   2024-03-16T23:54:26Z  AXGNb76QgH0
# 4   2024-03-08T17:15:08Z  AXGNb76QgH0
# 5   2024-03-04T13:20:15Z  AXGNb76QgH0
# 6   2024-02-24T20:26:58Z  AXGNb76QgH0
# 7   2024-02-16T14:32:43Z  AXGNb76QgH0
# 8   2024-02-15T11:52:27Z  AXGNb76QgH0
# 9   2024-02-13T13:47:24Z  AXGNb76QgH0
# 10  2024-02-13T12:47:22Z  AXGNb76QgH0
# 11  2024-02-13T11:20:00Z  AXGNb76QgH0
# 12  2024-01-28T09:04:16Z  AXGNb76QgH0
# 13  2024-01-21T15:41:29Z  AXGNb76QgH0
# 14  2024-01-11T18:35:05Z  AXGNb76QgH0
#
#                                               Comment
# 0   Ehy do you miss out the 500X its same and hybr...
# 1                          Enjoyed watching thank you
# 2               Nobody are liking the eye lits so far
# 3   Dont follow the worldly trends follow Jesus Ch...
# 4                               25000 is a fair price
# 5   It looks solid and I know its a great driving ...
# 6   Really love the video and review of new Fiat 6...
# 7   Imagine if Fiat invested in perfecting the 500...
# 8   OMG i hate you shoesThey look like someting ou...
# 9   My wife has a 500 C and all we love it Nobody ...
# 10                              Why are most EVs SUVs
# 11  Lovely quote from The Italian Job at the Lingo...
# 12                                       A french car
# 13                                 She doesnt like it
# 14  Ill pass because no rear door pockets just kid...

# %%
# Save as a new CSV file
df_600.to_csv('600e - YouTube_No Emojis and Punctuation.csv', index=False)

# %% [markdown]
# ## 500e

# %%
# Read csv file
df_500 = pd.read_csv('DataPull-500e.csv', engine='python', escapechar="\\")
df_500.head(15)
# Out:
#                Timestamp              Username      VideoID  \
# 0   2024-05-04T20:35:00Z        @miscetc-tm2yt  0kDbvxpjLZs
# 1   2024-02-16T11:44:20Z               @LucuYT  0kDbvxpjLZs
# 2   2024-02-13T22:37:50Z            @Lewis_mp3  0kDbvxpjLZs
# 3   2024-02-13T22:21:00Z          @mitchib1440  0kDbvxpjLZs
# 4   2024-01-06T11:27:45Z         @IMAN7THRYLOS  0kDbvxpjLZs
# 5   2023-10-21T11:33:22Z      @musiceditor7083  0kDbvxpjLZs
# 6   2023-09-16T04:33:48Z             @cmmartti  0kDbvxpjLZs
# 7   2023-08-17T22:03:40Z          @astra-rb6sz  0kDbvxpjLZs
# 8   2023-06-01T06:25:30Z          @BF4pawntard  0kDbvxpjLZs
# 9   2023-04-28T17:32:15Z            @o2barebel  0kDbvxpjLZs
# 10  2023-07-18T11:43:09Z                @tpv59  0kDbvxpjLZs
# 11  2023-04-06T06:18:43Z             @TB-up4xi  0kDbvxpjLZs
# 12  2022-12-02T20:51:14Z  @seasidegalaxystreet  0kDbvxpjLZs
# 13  2022-11-05T18:55:42Z        @piusdavidw...  0kDbvxpjLZs
# 14  2022-09-05T23:43:07Z       @jollygreen4662  0kDbvxpjLZs
#
#                                               Comment                  Date
# 0   9 seconds, for an electric car that's especial...  2024-05-04T20:35:00Z
# 1   Good honest review thanks.   Like the car  I’m...  2024-02-16T11:44:20Z
# 2                    This women is awfully irritating  2024-02-13T22:37:50Z
# 3   This presenter is absolutely amazing! More of ...  2024-02-13T22:21:00Z
# 4   This is a genius car. This is a car that you d...  2024-01-06T11:27:45Z
# 5   Got a Twinair Mito - done 60k in it & it's gre...  2023-10-21T11:33:22Z
# 6   No spare wheel is a dealbreaker. I love that g...  2023-09-16T04:33:47Z
# 7                                     I love this car  2023-08-17T22:03:40Z
# 8   I absolutely hate those big entertainment scre...  2023-06-01T06:25:30Z
# 9      Why are you driving in the middle of the road?  2023-04-28T17:32:15Z
# 10                               Yes, I noticed that.  2023-07-18T11:43:09Z
# 11  7:12 strangely aroused at this point...anyway....  2023-04-06T06:21:31Z
# 12                     Wait until Abarth works on it.  2022-12-02T20:51:14Z
# 13                                    ............ ..  2022-11-05T18:55:42Z
# 14                                    Selling in usa?  2022-09-05T23:43:07Z

# %%
# Drop column 'Username' and 'Date'
df_500 = df_500.drop(columns=['Username', 'Date'])
df_500.head(15)
# Out:
#                Timestamp      VideoID  \
# 0   2024-05-04T20:35:00Z  0kDbvxpjLZs
# 1   2024-02-16T11:44:20Z  0kDbvxpjLZs
# 2   2024-02-13T22:37:50Z  0kDbvxpjLZs
# 3   2024-02-13T22:21:00Z  0kDbvxpjLZs
# 4   2024-01-06T11:27:45Z  0kDbvxpjLZs
# 5   2023-10-21T11:33:22Z  0kDbvxpjLZs
# 6   2023-09-16T04:33:48Z  0kDbvxpjLZs
# 7   2023-08-17T22:03:40Z  0kDbvxpjLZs
# 8   2023-06-01T06:25:30Z  0kDbvxpjLZs
# 9   2023-04-28T17:32:15Z  0kDbvxpjLZs
# 10  2023-07-18T11:43:09Z  0kDbvxpjLZs
# 11  2023-04-06T06:18:43Z  0kDbvxpjLZs
# 12  2022-12-02T20:51:14Z  0kDbvxpjLZs
# 13  2022-11-05T18:55:42Z  0kDbvxpjLZs
# 14  2022-09-05T23:43:07Z  0kDbvxpjLZs
#
#                                               Comment
# 0   9 seconds, for an electric car that's especial...
# 1   Good honest review thanks.   Like the car  I’m...
# 2                    This women is awfully irritating
# 3   This presenter is absolutely amazing! More of ...
# 4   This is a genius car. This is a car that you d...
# 5   Got a Twinair Mito - done 60k in it & it's gre...
# 6   No spare wheel is a dealbreaker. I love that g...
# 7                                     I love this car
# 8   I absolutely hate those big entertainment scre...
# 9      Why are you driving in the middle of the road?
# 10                               Yes, I noticed that.
# 11  7:12 strangely aroused at this point...anyway....
# 12                     Wait until Abarth works on it.
# 13                                    ............ ..
# 14                                    Selling in usa?

# %%
# Function to remove emojis from a string
def remove_emojis(text):
    if text is None:
        return text
    emoji_pattern = re.compile(
        "["
        u"\U0001F600-\U0001F64F"  # emoticons
        u"\U0001F300-\U0001F5FF"  # symbols & pictographs
        u"\U0001F680-\U0001F6FF"  # transport & map symbols
        u"\U0001F700-\U0001F77F"  # alchemical symbols
        u"\U0001F780-\U0001F7FF"  # Geometric Shapes Extended
        u"\U0001F800-\U0001F8FF"  # Supplemental Arrows-C
        u"\U0001F900-\U0001F9FF"  # Supplemental Symbols and Pictographs
        u"\U0001FA00-\U0001FA6F"  # Chess Symbols
        u"\U0001FA70-\U0001FAFF"  # Symbols and Pictographs Extended-A
        u"\U00002702-\U000027B0"  # Dingbats
        u"\U000024C2-\U0001F251"
        "]+", flags=re.UNICODE)
    return emoji_pattern.sub(r'', text)

# Function to remove punctuation from a string
def remove_punctuation(text):
    if text is None:
        return text
    return re.sub(r'[^\w\s]', '', text)

# Apply the functions to the 'Comment' column
df_500['Comment'] = df_500['Comment'].apply(remove_emojis).apply(remove_punctuation)

# %%
# Preview the cleaned data
df_500.head(15)
# Out:
#                Timestamp      VideoID  \
# 0   2024-05-04T20:35:00Z  0kDbvxpjLZs
# 1   2024-02-16T11:44:20Z  0kDbvxpjLZs
# 2   2024-02-13T22:37:50Z  0kDbvxpjLZs
# 3   2024-02-13T22:21:00Z  0kDbvxpjLZs
# 4   2024-01-06T11:27:45Z  0kDbvxpjLZs
# 5   2023-10-21T11:33:22Z  0kDbvxpjLZs
# 6   2023-09-16T04:33:48Z  0kDbvxpjLZs
# 7   2023-08-17T22:03:40Z  0kDbvxpjLZs
# 8   2023-06-01T06:25:30Z  0kDbvxpjLZs
# 9   2023-04-28T17:32:15Z  0kDbvxpjLZs
# 10  2023-07-18T11:43:09Z  0kDbvxpjLZs
# 11  2023-04-06T06:18:43Z  0kDbvxpjLZs
# 12  2022-12-02T20:51:14Z  0kDbvxpjLZs
# 13  2022-11-05T18:55:42Z  0kDbvxpjLZs
# 14  2022-09-05T23:43:07Z  0kDbvxpjLZs
#
#                                               Comment
# 0   9 seconds for an electric car thats especially...
# 1   Good honest review thanks   Like the car  Im i...
# 2                    This women is awfully irritating
# 3   This presenter is absolutely amazing More of h...
# 4   This is a genius car This is a car that you do...
# 5   Got a Twinair Mito  done 60k in it  its great ...
# 6   No spare wheel is a dealbreaker I love that ga...
# 7                                     I love this car
# 8   I absolutely hate those big entertainment scre...
# 9       Why are you driving in the middle of the road
# 10                                 Yes I noticed that
# 11  712 strangely aroused at this pointanywayconce...
# 12                      Wait until Abarth works on it
# 13
# 14                                     Selling in usa

# %%
# Save as a new CSV file
df_500.to_csv('500e - YouTube_No Emojis and Punctuation.csv', index=False)
